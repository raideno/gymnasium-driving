# %%
import os
import numpy as np

data = np.load("/Users/nadir/Documents/research-project/code/experimentations/gymnasium/outputs/2026-02-08/18-40-37/evaluations/evaluations.npz")

data.keys()

print(data["timesteps"])

print(data["timesteps"].shape)
print(data["results"][0])
